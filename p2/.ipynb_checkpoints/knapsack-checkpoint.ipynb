# %% [markdown]
# # Project 2
# This is project 2. I did stuff.

# %%
import numpy as np
import pydotplus
import pprint as pp
import mlrose
import pandas as pd
import random
import datetime
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
# load local files
# %run util/util
# %run util/stats
# %run util/charts

# %%
max_trials = 10
rand_seeds = random.sample(range(1, 999999999), max_trials)

# %%
def print_groups(g):
    for key, item in g:
        print(g.get_group(key), "\n\n")

# %%
def show_aggregates(attempts):
    att_group = attempts.groupby('max-attemtps')
    fitness_agg = att_group['best-fit-score'].agg([np.mean, np.std, np.median, np.min, np.max])
    fitness_agg.columns = ['Fitness Mean', 'Fitness Std.', 'Fitness Median', 'Fitness Min', 'Fitness Max']
    time_agg = att_group['time'].agg([np.mean])
    time_agg.columns = ['Time Mean']
    data_agg_comb = pd.concat([fitness_agg, time_agg], axis=1, sort=False)
    return data_agg_comb

# %%
def try_problem(prob_f, attempt_max):
    attempts = []
    for a in range(1, attempt_max + 1):
        for t in range(len(rand_seeds)):
            seed = rand_seeds[t]
            start_time = datetime.datetime.now()
            best_state, best_fit_score = prob_f(a, seed)
            total_delta = datetime.datetime.now() - start_time
            microseconds  = total_delta.seconds * 1000000 + total_delta.microseconds
            attempts.append([a, t, best_state, best_fit_score, seed, microseconds])
    df = pd.DataFrame(attempts, columns=['max-attemtps', 'trial-n', 'best-state', 'best-fit-score', 'seed', 'time'])
    
    return df

# %%
def try_sim_ann(prob, initial_state, attempt_max):
    def p(attempts, seed):
        return mlrose.simulated_annealing(prob, schedule = mlrose.ExpDecay(), max_attempts = attempts, 
                                                              max_iters = 1000, init_state = initial_state, 
                                                              random_state = seed)
    return try_problem(p, attempt_max)

# %%
def try_genetic(prob, attempt_max):
    def p(attempts, seed):
        return mlrose.genetic_alg(prob, max_attempts=attempts, random_state=seed)
    return try_problem(p, attempt_max)

# %%
def try_rand_hill(prob, initial_state, attempt_max):
    def p(attempts, seed):
        return mlrose.random_hill_climb(prob, max_attempts=attempts, random_state=seed)
    return try_problem(p, attempt_max)

# %%
def try_mimic(prob, attempt_max):
    def p(attempts, seed):
        return mlrose.mimic(prob, max_attempts=attempts, random_state=seed)
    return try_problem(p, attempt_max)

# %%
def show_learning_rate(data, title, ylim=None, xlim=None):
    plt.plot(data['Fitness Mean'], 'b', data['Fitness Median'], 'r')
    plt.legend(['Mean Fitness', 'Median Fitness'], loc='lower right')
    plt.xlabel('iterations')
    plt.ylabel('fitness')
    if ylim is not None:
        plt.ylim(ylim[0],ylim[1])
    if xlim is not None:
        plt.xlim(xlim[0],xlim[1])
    plt.title(title)
    plt.show()

# %%
def show_learning_time(data, title):
    plt.plot(data['Time Mean'], 'gray')
    plt.legend(['Time Mean'], loc='lower right')
    plt.xlabel('iterations')
    plt.ylabel('time')
    plt.title(title)
    plt.show()

# %%
def show_charts(data, title, ylim=None):
    if ylim is None:
        ylim = [0,70]
    show_learning_rate(data, title, ylim=ylim)
    show_learning_time(data, title + ' Time')

# %% [markdown]
# # Knapsack

# %%
# modified from https://github.com/gkhayes/mlrose/blob/master/mlrose/fitness.py
def ks_fitness_fn(items, max_volume):
    def fit(state):
        volume = np.sum(items['volume'] * state)
        value = np.sum(items['value'] * state)
        
        if max_volume > volume:
            return value
        else:
            return 0
    return fit

# %%
items = pd.DataFrame([[1,5],[4,4],[6,1],[3,9],[5,2],[2,5],[1,1]], columns=['volume', 'value'])

# %%
ks_fitness = mlrose.CustomFitness(ks_fitness_fn(items, 55))
ks_problem = mlrose.DiscreteOpt(length = 7, fitness_fn = ks_fitness, maximize = True, max_val = 55)

# %%
ks_sim_ann = try_sim_ann(ks_problem, [0] * 7, 100)

# %%
ks_sim_ann
# Out:
#      max-attemtps  trial-n                    best-state  best-fit-score  \
# 0               1        0   [0, 47, 26, 39, 11, 46, 26]             0.0
# 1               1        1    [6, 38, 0, 10, 43, 30, 31]             0.0
# 2               1        2  [45, 22, 13, 39, 14, 18, 39]             0.0
# 3               1        3        [0, 0, 0, 0, 0, 0, 52]            52.0
# 4               1        4  [44, 14, 52, 22, 52, 48, 29]             0.0
# ..            ...      ...                           ...             ...
# 995           100        5        [0, 1, 0, 0, 10, 0, 0]            24.0
# 996           100        6        [52, 0, 0, 0, 0, 0, 0]           260.0
# 997           100        7       [22, 0, 0, 0, 0, 0, 32]           142.0
# 998           100        8        [6, 1, 0, 2, 0, 0, 37]            89.0
# 999           100        9    [42, 7, 38, 24, 43, 12, 8]             0.0
#
#           seed    time
# 0     18388634  709674
# 1    486362672  708793
# 2    394376559  694385
# 3    202308279    1442
# 4    147822652  692320
# ..         ...     ...
# 995   85669695   47132
# 996  773088299   55988
# 997  346218806   61223
# 998  511233270   50623
# 999  389116474  669881
#
# [1000 rows x 6 columns]

# %%
ks_sim_ann_agg = show_aggregates(ks_sim_ann)
ks_sim_ann_agg
# Out:
#               Fitness Mean  Fitness Std.  Fitness Median  Fitness Min  \
# max-attemtps
# 1                     32.9     42.293814            10.0          0.0
# 2                     41.4     63.734170            10.0          0.0
# 3                     41.4     63.734170            10.0          0.0
# 4                     41.4     63.734170            10.0          0.0
# 5                     42.9     64.264125            10.0          0.0
# ...                    ...           ...             ...          ...
# 96                    57.7     86.160122            12.0          0.0
# 97                    57.7     86.160122            12.0          0.0
# 98                    57.7     86.160122            12.0          0.0
# 99                    57.7     86.160122            12.0          0.0
# 100                   57.7     86.160122            12.0          0.0
#
#               Fitness Max  Time Mean
# max-attemtps
# 1                   115.0   350805.7
# 2                   200.0   349525.2
# 3                   200.0   347842.2
# 4                   200.0   350205.2
# 5                   200.0   349796.0
# ...                   ...        ...
# 96                  260.0   370740.2
# 97                  260.0   363824.0
# 98                  260.0   370227.3
# 99                  260.0   366783.4
# 100                 260.0   369298.7
#
# [100 rows x 6 columns]

# %%
show_charts(ks_sim_ann_agg, 'Knapsack Problem Simulated Annealing')

# %%
ks_fitness = mlrose.CustomFitness(ks_fitness_fn(items, 55))
ks_problem_2 = mlrose.DiscreteOpt(length = 7, fitness_fn = ks_fitness, maximize = True, max_val = 2)
ks_genetic = try_genetic(ks_problem_2, 100)

# %%
ks_genetic_agg = show_aggregates(ks_genetic)

# %%
ks_genetic_agg
# Out:
#               Fitness Mean  Fitness Std.  Fitness Median  Fitness Min  \
# max-attemtps
# 1                     27.0           0.0            27.0         27.0
# 2                     27.0           0.0            27.0         27.0
# 3                     27.0           0.0            27.0         27.0
# 4                     27.0           0.0            27.0         27.0
# 5                     27.0           0.0            27.0         27.0
# ...                    ...           ...             ...          ...
# 96                    27.0           0.0            27.0         27.0
# 97                    27.0           0.0            27.0         27.0
# 98                    27.0           0.0            27.0         27.0
# 99                    27.0           0.0            27.0         27.0
# 100                   27.0           0.0            27.0         27.0
#
#               Fitness Max  Time Mean
# max-attemtps
# 1                    27.0   215946.3
# 2                    27.0   287191.7
# 3                    27.0   356360.5
# 4                    27.0   429607.9
# 5                    27.0   508266.3
# ...                   ...        ...
# 96                   27.0  7092014.8
# 97                   27.0  7170292.1
# 98                   27.0  7230785.9
# 99                   27.0  7330759.5
# 100                  27.0  7359074.4
#
# [100 rows x 6 columns]

# %%
show_charts(ks_genetic_agg, 'Knapsack Genetic Algorithm', [0,10])

# %%
ks_rand_hill = try_rand_hill(ks_problem_2, [0] * 7, 100)

# %%
ks_rand_hill_agg
# Out:
#               Fitness Mean  Fitness Std.  Fitness Median  Fitness Min  \
# max-attemtps
# 1                     19.6      4.427189            20.0         12.0
# 2                     21.1      4.886489            22.0         12.0
# 3                     23.5      4.403282            24.0         13.0
# 4                     24.0      4.496913            26.5         13.0
# 5                     25.4      2.366432            27.0         22.0
# ...                    ...           ...             ...          ...
# 96                    27.0      0.000000            27.0         27.0
# 97                    27.0      0.000000            27.0         27.0
# 98                    27.0      0.000000            27.0         27.0
# 99                    27.0      0.000000            27.0         27.0
# 100                   27.0      0.000000            27.0         27.0
#
#               Fitness Max  Time Mean
# max-attemtps
# 1                    27.0     1122.0
# 2                    27.0     2214.7
# 3                    27.0     3294.3
# 4                    27.0     3839.0
# 5                    27.0     4563.2
# ...                   ...        ...
# 96                   27.0    36595.6
# 97                   27.0    36781.7
# 98                   27.0    36937.8
# 99                   27.0    38435.9
# 100                  27.0    38288.7
#
# [100 rows x 6 columns]

# %%
ks_rand_hill_agg = show_aggregates(ks_rand_hill)
show_charts(ks_rand_hill_agg, 'Knapsack Random Hill Climbling', [0,30])

# %%
ks_mimic = try_mimic(ks_problem_2, 100)

# %%
ks_mimic_agg = show_aggregates(ks_mimic)
show_charts(ks_mimic_agg, 'Knapsack MIMIC', [0,30])

# %%
ks_mimic_agg
# Out:
#               Fitness Mean  Fitness Std.  Fitness Median  Fitness Min  \
# max-attemtps
# 1                     27.0           0.0            27.0         27.0
# 2                     27.0           0.0            27.0         27.0
# 3                     27.0           0.0            27.0         27.0
# 4                     27.0           0.0            27.0         27.0
# 5                     27.0           0.0            27.0         27.0
# ...                    ...           ...             ...          ...
# 96                    27.0           0.0            27.0         27.0
# 97                    27.0           0.0            27.0         27.0
# 98                    27.0           0.0            27.0         27.0
# 99                    27.0           0.0            27.0         27.0
# 100                   27.0           0.0            27.0         27.0
#
#               Fitness Max  Time Mean
# max-attemtps
# 1                    27.0   222019.3
# 2                    27.0   292341.1
# 3                    27.0   373597.7
# 4                    27.0   442876.8
# 5                    27.0   520496.1
# ...                   ...        ...
# 96                   27.0  7390722.6
# 97                   27.0  7466160.0
# 98                   27.0  7558889.3
# 99                   27.0  7621032.1
# 100                  27.0  7698985.6
#
# [100 rows x 6 columns]
